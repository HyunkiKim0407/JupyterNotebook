# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df.
# Out:
# movie_title             object
# mcu_phase                int64
# release_date            object
# tomato_meter             int64
# audience_score           int64
# movie_duration           int64
# production_budget       object
# opening_weekend         object
# domestic_box_office     object
# worldwide_box_office    object
# dtype: object

# %%
df = pd.read_csv("/Users/ruben/Downloads/mcu_box_office.csv")
df
df['worldwide_box_office'] = df['worldwide_box_office'].str.replace(',', '').astype(float)f

df.plot(x='movie_title', y='worldwide_box_office', kind='bar')
plt.show()
# Out:
#   Cell In[103], line 3
#     df['worldwide_box_office'] = df['worldwide_box_office'].str.replace(',', '').astype(float)f
#                                                                                               ^
# SyntaxError: invalid syntax

# %%
df['worldwide_box_office'] = df['worldwide_box_office'].str.replace(',', '').astype(float)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[104], line 1
# ----> 1 df['worldwide_box_office'] = df['worldwide_box_office'].str.replace(',', '').astype(float)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/generic.py:6204, in NDFrame.__getattr__(self, name)
#    6197 if (
#    6198     name not in self._internal_names_set
#    6199     and name not in self._metadata
#    6200     and name not in self._accessors
#    6201     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6202 ):
#    6203     return self[name]
# -> 6204 return object.__getattribute__(self, name)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/accessor.py:224, in CachedAccessor.__get__(self, obj, cls)
#     221 if obj is None:
#     222     # we're accessing the attribute of the class, i.e., Dataset.geo
#     223     return self._accessor
# ...

# %%
df.plot(x = 'movie_title', y = 'worldwide_box_office', kind='bar',color = 'red' )
plt.show()

# %%
df.plot(kind = 'pie', y = 'worldwide_box_office')
plt.legend(False)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[126], line 2
#       1 df.plot(kind = 'pie', y = 'worldwide_box_office')
# ----> 2 plt.legend(False)
#       3 plt.show()
#
# File ~/anaconda3/lib/python3.11/site-packages/matplotlib/pyplot.py:3372, in legend(*args, **kwargs)
#    3370 @_copy_docstring_and_deprecators(Axes.legend)
#    3371 def legend(*args, **kwargs) -> Legend:
# -> 3372     return gca().legend(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/matplotlib/axes/_axes.py:322, in Axes.legend(self, *args, **kwargs)
#     204 @_docstring.dedent_interpd
#     205 def legend(self, *args, **kwargs):
#     206     """
#     207     Place a legend on the Axes.
#     208
#    (...)
#     320     .. plot:: gallery/text_labels_and_annotations/legend.py
#     321     """
# ...

# %%
fig, ax = plt.subplots()

# 그래프를 그립니다.
df.plot(kind='pie', y='worldwide_box_office', ax=ax)

# 그래프의 위치를 변경합니다.
ax.set_position([0.1, 0.1, 0.5, 0.8])  # [left, bottom, width, height]

plt.show()

# %%
df.plot(kind = 'pie', width = 6)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[102], line 1
# ----> 1 df.plot(kind = 'pie', width = 6)
#       2 plt.show()
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/plotting/_core.py:982, in PlotAccessor.__call__(self, *args, **kwargs)
#     980 if isinstance(data, ABCDataFrame):
#     981     if y is None and kwargs.get("subplots") is False:
# --> 982         raise ValueError(
#     983             f"{kind} requires either y column or 'subplots=True'"
#     984         )
#     985     if y is not None:
#     986         if is_integer(y) and not data.columns._holds_integer():
#
# ValueError: pie requires either y column or 'subplots=True'

# %%
from PIL import Image
from PIL import ImageDraw
from PIL import ImageFont


image = Image.open('/Users/ruben/Downloads/infinity_stones.png')
draw = ImageDraw.Draw(image)

font = ImageFont.truetype('/System/Library/Fonts/Supplemental/Arial.ttf', 200)

x, y = 600, 600
draw.text((x, y), 'Timestone', fill = 'red',font = font)



plt.imshow(image)
plt.show()

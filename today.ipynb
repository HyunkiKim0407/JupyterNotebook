# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import rc
import seaborn as sns

rc('font', family='AppleGothic')

plt.rcParams['axes.unicode_minus'] = False
# plt.xticks(np.arange(3), step = 2)
total_len = len(df.index)

df = pd.read_csv('시도별 학교수.csv',encoding='cp949')

df.plot(kind = 'bar', y = '서울')
df.plot(kind = 'bar', y = '충북', color ='r')
# plt.xticks(np.arange(0, df['서울'].max(), step=50))  # 간격을 5로 설정

#plt.show()

# print(df.to_string())
# Out:
# <Axes: >

# %%
df.loc[1:2]
# Out:
#      연도     계   서울  부산  대구  인천  광주  대전  울산  세종   경기   강원   충북   충남   전북   전남  \
# 1  1966  5274  177  86   0   0   0   0   0   0  579  538  334  531  481  779
# 2  1967  5418  185  93   0   0   0   0   0   0  600  554  341  555  500  794
#
#     경북   경남  제주
# 1  886  787  96
# 2  899  799  98
